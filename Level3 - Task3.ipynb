# %% [markdown]
# # Task: Data Visualization
#
# Create visualizations to represent the distribution
# of ratings using different charts (histogram, bar
# plot, etc.).
#
# Compare the average ratings of different cuisines
# or cities using appropriate visualizations.
#
# Visualize the relationship between various
# features and the target variable to gain insights.

# %% [markdown]
# # Step 1:
#   Import Libraries and Load Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r"C:\Users\HP\Downloads\Dataset_cleaned .csv")

# Display the first few rows
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # Step 2:
#    Distribution of Ratings using Histogram

# %% [markdown]
# Explanation: We import the libraries and load the cleaned dataset to start exploring.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Aggregate rating'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Restaurant Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Explanation: This histogram shows how the ratings are distributed.
# The kde=True adds a smooth curve over the histogram for better visualization.

# %% [markdown]
# # Step 3:
#    Bar Plot of Count of Ratings

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Aggregate rating', data=df, palette='mako')
plt.title('Count of Each Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Number of Restaurants')
plt.show()

# %% [markdown]
# Explanation: This bar plot shows how many restaurants received each rating value.

# %% [markdown]
# # Step 4:
#    Compare Average Ratings by Cuisine

# %% [markdown]
# 4.1 Preprocess the Cuisines column (for multi-cuisine handling)

# %%
import pandas as pd

# Load the dataset (make sure the path is correct)
df = pd.read_csv(r"C:\Users\HP\Downloads\Dataset_cleaned .csv")

# Optional: Check the first few rows to confirm it's loaded
df.head()

# Step to handle multiple cuisines
df_cuisine = df.copy()
df_cuisine['Cuisines'] = df_cuisine['Cuisines'].astype(str)
df_cuisine = df_cuisine.assign(Cuisines=df_cuisine['Cuisines'].str.split(', ')).explode('Cuisines')

# Optional: view results
df_cuisine.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 0        6317637        Le Petit Souffle           162       Makati City
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 0   Century City Mall, Poblacion, Makati City
# 0   Century City Mall, Poblacion, Makati City
# ...

# %% [markdown]
# Explanation: If a restaurant serves multiple cuisines, we split them into individual rows.

# %% [markdown]
# 4.2 Create bar plot of top cuisines by average rating

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv(r"C:\Users\HP\Downloads\Dataset_cleaned .csv")

# Handle multi-cuisine entries
df_cuisine = df.copy()
df_cuisine['Cuisines'] = df_cuisine['Cuisines'].astype(str)
df_cuisine = df_cuisine.assign(Cuisines=df_cuisine['Cuisines'].str.split(', ')).explode('Cuisines')

# Calculate average rating per cuisine
avg_rating_cuisine = df_cuisine.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False).head(10)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=avg_rating_cuisine.values, y=avg_rating_cuisine.index, palette='crest')
plt.title('Top 10 Cuisines by Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Cuisine')
plt.show()

# %% [markdown]
# Explanation: We display the top 10 cuisines based on their average rating.

# %% [markdown]
# # Step 5:
#    Compare Average Ratings by City

# %%
avg_rating_city = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=avg_rating_city.values, y=avg_rating_city.index, palette='flare')
plt.title('Top 10 Cities by Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('City')
plt.show()

# %% [markdown]
# Explanation: This bar plot helps compare which cities have the highest-rated restaurants.

# %% [markdown]
# # Step 6:
#    Relationship - Votes vs Ratings

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Aggregate rating', y='Votes', data=df, alpha=0.6)
plt.title('Votes vs Ratings')
plt.xlabel('Aggregate Rating')
plt.ylabel('Votes')
plt.show()

# %% [markdown]
# Explanation: This scatter plot checks if higher-rated restaurants receive more customer votes.

# %% [markdown]
# # Step 7:
#    Relationship - Price Range vs Rating

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Price range', y='Aggregate rating', data=df, palette='coolwarm')
plt.title('Rating Distribution by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Aggregate Rating')
plt.show()

# %% [markdown]
# Explanation: This boxplot helps understand how ratings vary across different price ranges.

# %% [markdown]
# Final Recap – Visualization Steps
#
# Step 2: Histogram
# ➤ Shows how restaurant ratings are spread out (distribution).
#
# Step 3: Bar Plot
# ➤ Shows how many restaurants got each rating.
#
# Step 4: Bar Plot (Horizontal)
# ➤ Compares average ratings of different cuisines.
#
# Step 5: Bar Plot (Horizontal)
# ➤ Compares average ratings of different cities.
#
# Step 6: Scatter Plot
# ➤ Shows the relationship between votes and ratings.
#
# Step 7: Boxplot
# ➤ Shows how price range affects ratings.
